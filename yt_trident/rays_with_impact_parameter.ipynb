# %%
import numpy as np
from numpy import pi as pi
import matplotlib.pyplot as plt
plt.ion()
import yt
import glob
from tools import get_2Mpc_LG_dataset, get_mw_center_2Mpc_LG, ray_start_from_sph, make_projection, plot_ray_in_projection

# %%
rays_directory = './rays_2Mpc_LG_to_mw_impact/'

ds = get_2Mpc_LG_dataset()

mw_center = get_mw_center_2Mpc_LG()

theta_away = 1.036
phi_away = 1.314
# Out:
# yt : [INFO     ] 2019-01-18 00:12:33,643 Calculating time from 1.000e+00 to be 4.336e+17 seconds
# yt : [INFO     ] 2019-01-18 00:12:33,682 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:12:33,683 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:12:33,684 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-01-18 00:12:33,685 Parameters: domain_right_edge         = [64000. 64000. 64000.]
# yt : [INFO     ] 2019-01-18 00:12:33,686 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:12:33,687 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:12:33,687 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:12:33,688 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:12:33,688 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:12:33,741 Allocating for 1.111e+07 particles (index particle type 'all')
# yt : [INFO     ] 2019-01-18 00:12:35,984 Identified 7.123e+05 octs
# /home/martin/Downloads/anaconda3/lib/python3.6/site-packages/yt/units/yt_array.py:978: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   ret = super(YTArray, self).__getitem__(item)
# /home/martin/Downloads/anaconda3/lib/python3.6/site-packages/yt/fields/fluid_fields.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   new_field[slice_3d] = f
# yt : [WARNING  ] 2019-01-18 00:12:37,127 Field ('gas', 'pressure') already exists. To override use force_override=True.
# /media/storage/Documents/FCEN/Tesis/thesis/yt_trident/tools.py:72: UserWarning: Because 'sampling_type' not specified, yt will assume a cell 'sampling_type'
#   ds.add_field(("gas", "pressure"), function=_pressure, units="dyne/cm**2")

# %%
px = make_projection(ds, mw_center, 4000, 'x')
# Out:
# yt : [INFO     ] 2019-01-18 00:07:20,764 Projection completed
# yt : [INFO     ] 2019-01-18 00:07:20,832 xlim = 30713.013672 34713.013672
# yt : [INFO     ] 2019-01-18 00:07:20,833 ylim = 30897.257812 34897.257812
# yt : [INFO     ] 2019-01-18 00:07:20,833 xlim = 30713.013672 34713.013672
# yt : [INFO     ] 2019-01-18 00:07:20,834 ylim = 30897.257812 34897.257812
# yt : [INFO     ] 2019-01-18 00:07:20,836 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for handle in glob.glob('./rays_2Mpc_LG_to_mw_impact/ray*'):
    ray = yt.load(handle);
    plot_ray_in_projection(px, ray);
# Out:
# yt : [INFO     ] 2019-01-18 00:08:18,760 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:08:18,762 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:08:18,764 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,767 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,769 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:08:18,771 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:08:18,773 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:08:18,775 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:08:18,776 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:08:18,858 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:08:18,858 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:08:18,858 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,859 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,859 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:08:18,859 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:08:18,860 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:08:18,860 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:08:18,860 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:08:18,917 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:08:18,918 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:08:18,919 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,919 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,920 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:08:18,920 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:08:18,920 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:08:18,920 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:08:18,921 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:08:18,977 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:08:18,977 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:08:18,978 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,978 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:08:18,978 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:08:18,979 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:08:18,979 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:08:18,979 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:08:18,979 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:08:19,068 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:08:19,068 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:08:19,069 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:08:19,070 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:08:19,070 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:08:19,070 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:08:19,070 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:08:19,071 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:08:19,071 Parameters: hubble_constant           = 0.7

# %%
px.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
px.zoom(2)
# Out:
# yt : [INFO     ] 2019-01-18 00:09:04,852 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
center = (ray_start_from_sph(mw_center, (2000, theta_away, phi_away)) - mw_center)/2 + mw_center

# %%
center
# Out:
# array([22036.34244889, 33545.17332383, 33406.92362769])

# %%
px_centered = make_projection(ds, center, 2500, 'x')
# Out:
# yt : [INFO     ] 2019-01-18 00:25:25,428 Projection completed
# yt : [INFO     ] 2019-01-18 00:25:25,429 xlim = 32295.173324 34795.173324
# yt : [INFO     ] 2019-01-18 00:25:25,429 ylim = 32156.923628 34656.923628
# yt : [INFO     ] 2019-01-18 00:25:25,430 xlim = 32295.173324 34795.173324
# yt : [INFO     ] 2019-01-18 00:25:25,430 ylim = 32156.923628 34656.923628
# yt : [INFO     ] 2019-01-18 00:25:25,431 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px_centered.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for handle in glob.glob('./rays_2Mpc_LG_to_mw_impact/ray*'):
    ray = yt.load(handle);
    plot_ray_in_projection(px_centered, ray);
# Out:
# yt : [INFO     ] 2019-01-18 00:25:26,204 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:25:26,205 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:25:26,206 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,206 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,207 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:25:26,207 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:25:26,207 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:25:26,207 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:25:26,208 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:25:26,257 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:25:26,257 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:25:26,258 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,258 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,259 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:25:26,259 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:25:26,259 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:25:26,260 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:25:26,260 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:25:26,311 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:25:26,312 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:25:26,312 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,312 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,313 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:25:26,313 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:25:26,313 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:25:26,314 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:25:26,314 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:25:26,370 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:25:26,370 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:25:26,371 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,371 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,372 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:25:26,372 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:25:26,372 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:25:26,372 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:25:26,373 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2019-01-18 00:25:26,439 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2019-01-18 00:25:26,439 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2019-01-18 00:25:26,440 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,440 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# yt : [INFO     ] 2019-01-18 00:25:26,441 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2019-01-18 00:25:26,441 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2019-01-18 00:25:26,441 Parameters: omega_lambda              = 0.721
# yt : [INFO     ] 2019-01-18 00:25:26,442 Parameters: omega_matter              = 0.279
# yt : [INFO     ] 2019-01-18 00:25:26,442 Parameters: hubble_constant           = 0.7

# %%
px_centered.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
px_centered.zoom(1.25)
# Out:
# yt : [INFO     ] 2019-01-18 00:26:08,695 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
