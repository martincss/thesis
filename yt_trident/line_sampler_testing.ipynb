# %%
run line_sampler.py
# Out:
# /home/martin/Downloads/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# yt : [INFO     ] 2018-10-10 19:17:55,479 Calculating time from 1.000e+00 to be 4.336e+17 seconds
# yt : [INFO     ] 2018-10-10 19:17:55,493 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2018-10-10 19:17:55,494 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2018-10-10 19:17:55,495 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-10-10 19:17:55,495 Parameters: domain_right_edge         = [64000. 64000. 64000.]
# yt : [INFO     ] 2018-10-10 19:17:55,496 Parameters: cosmological_simulation   = 1
# ...

# %%
from tools import make_projection

# %%
density = ds.r[("Gas","density")]
wdens = np.where(density == np.max(density))
coordinates = ds.r[("Gas","Coordinates")]
center = coordinates[wdens][0]

px = make_projection(ds, mw_center, 2000)
#px = make_projection(ds, center, 1000)
# Out:
# yt : [INFO     ] 2018-10-10 19:38:26,688 Projection completed
# yt : [INFO     ] 2018-10-10 19:38:26,688 xlim = 31715.150391 33715.150391
# yt : [INFO     ] 2018-10-10 19:38:26,689 ylim = 31897.707031 33897.707031
# yt : [INFO     ] 2018-10-10 19:38:26,689 xlim = 31715.150391 33715.150391
# yt : [INFO     ] 2018-10-10 19:38:26,690 ylim = 31897.707031 33897.707031
# yt : [INFO     ] 2018-10-10 19:38:26,691 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
px.annotate_ray(ray_from_mw, arrow=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
mw_center = subhalo_center(subfind_path=subfind_path, snap_num=snap_num,
            subhalo_number = 1)
mw_center
# Out:
# array([21819.64 , 32715.15 , 32897.707], dtype=float32)

# %%
center
# Out:
# YTArray([21820.02929688, 32714.43164062, 32897.40234375]) code_length

# %%
ray2 = make_ray_from_mw((1000, 0.1, 0.5), './rays_2Mpc_LG/ray_1000_0.1_0.h5')
# Out:
# yt : [INFO     ] 2018-10-10 20:06:39,614 Getting segment at z = 2.220446049250313e-16: [2.0321128e-20 3.0468364e-20 3.0638385e-20] unitary to [0.00136894 0.00074785 0.01554694] unitary.
# yt : [INFO     ] 2018-10-10 20:06:39,616 Getting subsegment: [2.0321128004327155e-20 unitary, 3.0468364220429686e-20 unitary, 3.063838537922628e-20 unitary] to [0.0013689385241123818 unitary, 0.000747854524165678 unitary, 0.015546940082469153 unitary].
# /home/martin/Downloads/anaconda3/lib/python3.6/site-packages/yt/units/yt_array.py:1314: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-4725ec633c1a> in <module>()
# ----> 1 ray2 = make_ray_from_mw((1000, 0.1, 0.5), './rays_2Mpc_LG/ray_1000_0.1_0.h5')
#
# ...

# %%
ray_end = ray_end_from_sph(mw_center, (1000, 0., ))

# %%
ray2 = trident.make_simple_ray(ds,
                                  start_position=mw_center,
                                  end_position=ray_end,
#                                  trajectory=spherical_coords,
                                  data_filename='./rays_2Mpc_LG/ray_1000_0.1_0.h5',
                                  lines=line_list,
                                  ftype='Gas')
# Out:
# yt : [INFO     ] 2018-10-10 20:08:13,302 Getting segment at z = 2.220446049250313e-16: [0.3409319  0.51117426 0.5140267 ] unitary to [0.34403609 0.51117422 0.52934021] unitary.
# yt : [INFO     ] 2018-10-10 20:08:13,304 Getting subsegment: [0.34093189239501953 unitary, 0.5111742615699768 unitary, 0.5140267014503479 unitary] to [0.3440360930592979 unitary, 0.5111742248535156 unitary, 0.5293402126420507 unitary].
# yt : [INFO     ] 2018-10-10 20:08:28,529 Saving field data to yt dataset: ./rays_2Mpc_LG/ray_1000_0.1_0.h5.
# yt : [INFO     ] 2018-10-10 20:08:28,680 Parameters: current_time              = 4.336488085281229e+17 s
# yt : [INFO     ] 2018-10-10 20:08:28,681 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2018-10-10 20:08:28,681 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2018-10-10 20:08:28,682 Parameters: domain_right_edge         = [64000. 64000. 64000.] code_length
# ...

# %%
px.annotate_ray(ray2, arrow=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
